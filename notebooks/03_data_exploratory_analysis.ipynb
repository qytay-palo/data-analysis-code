# %%
# data processing
import polars as pl
import numpy as np

#visualisation
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
INFECTIOUS_DISEASE_DATA_AI_CLEANED_DIR = "../datasets/weekly-infectious-disease-bulletin-cases-AI-cleaned.parquet"
INFECTIOUS_DISEASE_DATA_CLEANED_DIR = "../datasets/weekly-infectious-disease-bulletin-cases-cleaned.csv"

# %%
df_ai_cleaned = pl.read_parquet(INFECTIOUS_DISEASE_DATA_AI_CLEANED_DIR)
df_cleaned = pl.read_csv(INFECTIOUS_DISEASE_DATA_CLEANED_DIR)

# %%
df_cleaned
# Out:
# shape: (16_066, 3)
# ┌──────────┬──────────────────────────┬──────────────┐
# │ epi_week ┆ disease                  ┆ no._of_cases │
# │ ---      ┆ ---                      ┆ ---          │
# │ str      ┆ str                      ┆ i64          │
# ╞══════════╪══════════════════════════╪══════════════╡
# │ 2012-W01 ┆ Avian Influenza          ┆ 0            │
# │ 2012-W01 ┆ Nipah virus infection    ┆ 0            │
# │ 2012-W01 ┆ Plague                   ┆ 0            │
# │ 2012-W01 ┆ Poliomyelitis            ┆ 0            │
# │ …        ┆ …                        ┆ …            │
# │ 2020-W53 ┆ Hand, Foot Mouth Disease ┆ 0            │
# │ 2020-W53 ┆ Acute Viral hepatitis B  ┆ 1            │
# │ 2020-W53 ┆ Acute Viral hepatitis C  ┆ 0            │
# │ 2020-W53 ┆ Melioidosis              ┆ 0            │
# └──────────┴──────────────────────────┴──────────────┘

# %%
df_ai_cleaned
# Out:
# shape: (16_066, 10)
# ┌─────────────┬──────┬──────┬─────────────┬───┬────────────┬────────────┬─────────────┬────────────┐
# │ epidemiolog ┆ year ┆ week ┆ week_start_ ┆ … ┆ case_count ┆ is_outlier ┆ transmissio ┆ burden_tie │
# │ ical_week   ┆ ---  ┆ ---  ┆ date        ┆   ┆ ---        ┆ ---        ┆ n_mode      ┆ r          │
# │ ---         ┆ i32  ┆ i32  ┆ ---         ┆   ┆ i64        ┆ bool       ┆ ---         ┆ ---        │
# │ str         ┆      ┆      ┆ date        ┆   ┆            ┆            ┆ str         ┆ str        │
# ╞═════════════╪══════╪══════╪═════════════╪═══╪════════════╪════════════╪═════════════╪════════════╡
# │ 2012-W01    ┆ 2012 ┆ 1    ┆ 2012-01-02  ┆ … ┆ 6          ┆ false      ┆ Other       ┆ High       │
# │ 2012-W01    ┆ 2012 ┆ 1    ┆ 2012-01-02  ┆ … ┆ 0          ┆ false      ┆ Vaccine-pre ┆ Low        │
# │             ┆      ┆      ┆             ┆   ┆            ┆            ┆ ventable    ┆            │
# │ 2012-W02    ┆ 2012 ┆ 2    ┆ 2012-01-09  ┆ … ┆ 0          ┆ false      ┆ Other       ┆ Medium     │
# │ 2012-W02    ┆ 2012 ┆ 2    ┆ 2012-01-09  ┆ … ┆ 0          ┆ false      ┆ Other       ┆ Low        │
# │ …           ┆ …    ┆ …    ┆ …           ┆ … ┆ …          ┆ …          ┆ …           ┆ …          │
# │ 2020-W53    ┆ 2020 ┆ 53   ┆ 2020-12-28  ┆ … ┆ 193        ┆ false      ┆ Vector-born ┆ High       │
# │             ┆      ┆      ┆             ┆   ┆            ┆            ┆ e           ┆            │
# │ 2020-W53    ┆ 2020 ┆ 53   ┆ 2020-12-28  ┆ … ┆ 0          ┆ false      ┆ Other       ┆ High       │
# │ 2020-W53    ┆ 2020 ┆ 53   ┆ 2020-12-28  ┆ … ┆ 0          ┆ false      ┆ Vaccine-pre ┆ Low        │
# │             ┆      ┆      ┆             ┆   ┆            ┆            ┆ ventable    ┆            │
# │ 2020-W53    ┆ 2020 ┆ 53   ┆ 2020-12-28  ┆ … ┆ 0          ┆ false      ┆ Other       ┆ Low        │
# └─────────────┴──────┴──────┴─────────────┴───┴────────────┴────────────┴─────────────┴────────────┘

# %%
# grouping total cases by diseases for both AI processes and original datasets
df_cleaned.group_by("disease").agg(pl.sum("no._of_cases")).sort("no._of_cases", descending=True)
df_ai_cleaned.group_by("disease_name").agg(pl.sum("case_count")).sort("case_count", descending=True)
# Out:
# shape: (42, 2)
# ┌───────────────────────────────────┬────────────┐
# │ disease_name                      ┆ case_count │
# │ ---                               ┆ ---        │
# │ str                               ┆ i64        │
# ╞═══════════════════════════════════╪════════════╡
# │ Hand, Foot and Mouth Disease      ┆ 235409     │
# │ Dengue Fever                      ┆ 126642     │
# │ Salmonellosis(non-enteric fevers… ┆ 16497      │
# │ Mumps                             ┆ 4213       │
# │ …                                 ┆ …          │
# │ Nipah virus infection             ┆ 0          │
# │ SARS                              ┆ 0          │
# │ Plague                            ┆ 0          │
# │ Japanese Encephalitis             ┆ 0          │
# └───────────────────────────────────┴────────────┘

# %%
grouped_ai_values = (
    df_ai_cleaned
    .group_by(["disease_name", "burden_tier"])
    .agg(pl.sum("case_count").alias("total_cases"))
)

grouped_orig_values = (
    df_cleaned
    .group_by("disease")
    .agg(pl.sum("no._of_cases"))
    .sort("no._of_cases", descending=True)
)

# Interactive bar chart

def hover_bar_chart(df : pl.DataFrame, x: str, y: str, hover_data: dict, title: str, color: str = ""):
        
    fig = px.bar(
        df,
        x=x,
        y=y,
        color=color if color else None,  # same as hue
        hover_data=hover_data,
        title=title
    )
    fig.show()

hover_bar_chart(grouped_ai_values, "disease_name", "total_cases", {"total_cases": True, "disease_name": True, "burden_tier": True}, "Total Cases by Disease and Burden Tier", "burden_tier")
hover_bar_chart(grouped_orig_values, "disease", "no._of_cases", {"no._of_cases": True, "disease": True}, "Total Cases by Disease")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 29
#      26     fig.show()
#      28 hover_bar_chart(grouped_ai_values, "disease_name", "total_cases", "burden_tier", {"total_cases": True, "disease_name": True, "burden_tier": True}, "Total Cases by Disease and Burden Tier")
# ---> 29 hover_bar_chart(grouped_orig_values, "disease", "no._of_cases", "", {"no._of_cases": True, "disease": True}, "Total Cases by Disease")
#
# Cell In[131], line 18, in hover_bar_chart(df, x, y, color, hover_data, title)
#      16 def hover_bar_chart(df : pl.DataFrame, x: str, y: str, color: str, hover_data: dict, title: str):
# ---> 18     fig = px.bar(
#      19         df,
#      20         x=x,
#      21         y=y,
#      22         color=color,  # same as hue
#      23         hover_data=hover_data,
#      24         title=title
#      25     )
#      26     fig.show()
#
# File ~/Documents/GitHub/gen-e2-data-analysis-MOH/.venv/lib/python3.9/site-packages/plotly/express/_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File ~/Documents/GitHub/gen-e2-data-analysis-MOH/.venv/lib/python3.9/site-packages/plotly/express/_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/Documents/GitHub/gen-e2-data-analysis-MOH/.venv/lib/python3.9/site-packages/plotly/express/_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/Documents/GitHub/gen-e2-data-analysis-MOH/.venv/lib/python3.9/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['disease', 'no._of_cases'] but received:
